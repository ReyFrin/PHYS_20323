# %%
a = 587
print(a)
# Out:
# 587

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot([1,2,3],[4,5,6])
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# Hello

# %%
i = 1
j = 219089
k = -21231
print (i,j,k)
# Out:
# 1 219089 -21231

# %%
d = complex(4.,-1.)
print(d)
# Out:
# (4-1j)

# %%
a = 1
b = 2
print(a+b)
# Out:
# 3

# %%
3. * 2.
# Out:
# 6.0

# %%
complex (2.,4.) - complex(1.,6.)
# Out:
# (1-2j)

# %%
3 * 9.2
# Out:
# 27.599999999999998

# %%
print(4**3, (3.4)**2 + 2, complex(1,1)**2)
# Out:
# 64 13.559999999999999 2j

# %% [markdown]
# int   float          complex

# %%
s = "Spam egg spam spam"

# %%
s[5]
# Out:
# 'e'

# %%
s[-1]
# Out:
# 'm'

# %%
s[5] = 'r'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 s[5] = 'r'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ^^ error showing it doesn't work

# %%
len(s)
# Out:
# 18

# %%
p = "hello, " + "my" + " world!" + s

# %%
len(p)
# Out:
# 34

# %%
s.upper()
# Out:
# 'SPAM EGG SPAM SPAM'

# %%
s.index('egg')
# Out:
# 5

# %%
p.split()
# Out:
# ['hello,', 'my', 'world!Spam', 'egg', 'spam', 'spam']

# %% [markdown]
# ^^ I don't know where the space I'm missing is

# %%
li = [4,5.5,'spam']

# %%
li[2]
# Out:
# 'spam'

# %%
li[2][0]
# Out:
# 's'

# %%
li[1] = -2.2

# %%
print(li)
# Out:
# [4, -2.2, 'spam']

# %%
li.append(-3)

# %%
print(li)
# Out:
# [4, -2.2, 'spam', -3]

# %%
li.insert(1, 3.14)

# %%
print(li)
# Out:
# [4, 3.14, -2.2, 'spam', -3]

# %%
len(li)
# Out:
# 5

# %%
li = [4,67,4,2,4,6,57,97]

# %%
list_new = li.sort()

# %%
print(list_new)
# Out:
# None

# %%
print(li)
# Out:
# [2, 4, 4, 4, 6, 57, 67, 97]

# %%
li[0:2]
# Out:
# [2, 4]

# %%
li[:2] #"start" defaults to 0
# Out:
# [2, 4]

# %%
li[2:] #"end" defaults to last element
# Out:
# [4, 4, 6, 57, 67, 97]

# %%
li[1::2] #specify to step size (starting at position 1, skip every 2)
# Out:
# [4, 4, 57, 97]

# %%
a = "Hello, egg world!"

# %%
print(a)
# Out:
# ['Hello,', 'world!']

# %% [markdown]
# ^^ I made 'a' a list and then removed egg but I don't know how to change it back

# %%
print(a[0:7]+a[11:])

# %% [markdown]
# ^^ correct answer
